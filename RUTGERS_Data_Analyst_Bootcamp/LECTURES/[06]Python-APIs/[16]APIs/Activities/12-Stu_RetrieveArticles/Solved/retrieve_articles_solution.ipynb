# %%
# Dependencies
import requests
from config import api_key
import time
# Created a variable 'URL' to hold the URL of the API
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
# Query is a request for specific information or data from a database
query = "obama"

# Search for articles published between a begin and end date
# Beginning== Jan 1 2016
# Ending== Jan 30 2016
begin_date = "20160101"
end_date = "20160130"

# Build URL
# <begin_date={}> as a query parameter with the key "begin_date"
# <end_date={}> as a query parameter with the key "end_date" 
query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"

# %%
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=WeYDppFuXumOVGiJC3ViYGcYzqhO1pE2&q=obama&begin_date=20160101&end_date=20160130'

# %%
# Retrieve articles
# <requests.get()> function for making a GET request
# <.json()> parsing the JSON content from the response and converts to a Python {}
articles = requests.get(query_url).json()

# <articles["response"]["docs"]> Withing the "response" {} accesses the "docs" key
articles_list = articles["response"]["docs"]

# <for article in> for loop to interate each value in 'articles_list'
for article in articles_list:
    
    # <{article["snippet"]}> Within the "article" {} accesses the "snippet" key.
    print(f'A snippet from the article: {article["snippet"]}')
    print('---------------------------')
# Out:
# A snippet from the article: In presidential elections, opposites attract.
# ---------------------------
# A snippet from the article: “We must confront the reality that around the world anti-Semitism is on the rise,” the president urged at an event to posthumously honor individuals who protected Jews during the Holocaust.
# ---------------------------
# A snippet from the article: President Obama hosted the emir of Qatar, Sheikh Tamim bin Hamad al-Thani, on Tuesday, and both said they were committed to defeating the Islamic State and other terrorist organizations.
# ---------------------------
# A snippet from the article: President Obama signed a presidential memorandum creating a White House task force on cancer.
# ---------------------------
# A snippet from the article: To function properly, the clemency process needs to be removed from the grasp of the Justice Department.
# ---------------------------
# A snippet from the article: The president seeks $4 billion to help states expand in an area he views as critical to young people’s success in a changing job market.
# ---------------------------
# A snippet from the article: Katie Beirne Fallon, the president’s legislative director, has been credited with improving his relations with lawmakers on Capitol Hill.
# ---------------------------
# A snippet from the article: The practice can lead to “devastating, lasting psychological consequences,” he said in an opinion article in The Washington Post.
# ---------------------------
# A snippet from the article: President Obama, speaking at the North American International Auto Show in Detroit, expressed sympathy and concern for residents of Flint, Mich., where there has been lead contamination in the drinking water.
# ---------------------------
# A snippet from the article: The first time the president met with House Democrats, in 2009, there were 257 of them. Now there are 188. Some point a finger at him.
# ---------------------------

# %%
articles_list
# Out:
# [{'abstract': 'In presidential elections, opposites attract.',
#   'web_url': 'https://www.nytimes.com/2016/01/25/opinion/campaign-stops/the-obama-theory-of-trump.html',
#   'snippet': 'In presidential elections, opposites attract.',
#   'lead_paragraph': 'It was so obvious, I’m embarrassed I missed it.',
#   'print_section': 'A',
#   'print_page': '21',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#     'height': 393,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 393},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blog480.jpg',
#     'height': 314,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blog427.jpg',
#     'height': 279,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-tmagArticle.jpg',
#     'height': 387,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-jumbo.jpg',
#     'height': 670,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blog225.jpg',
#     'height': 147,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master675.jpg',
#     'height': 442,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master180.jpg',
#     'height': 118,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master768.jpg',
#     'height': 503,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-popup.jpg',
#     'height': 425,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blog533.jpg',
#     'height': 349,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-tmagSF.jpg',
#     'height': 237,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-slide.jpg',
#     'height': 393,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-superJumbo.jpg',
#     'height': 1340,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master1050.jpg',
#     'height': 687,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master495.jpg',
#     'height': 324,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-master315.jpg',
#     'height': 206,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-articleInline.jpg',
#     'height': 124,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-hpSmall.jpg',
#     'height': 107,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blogSmallInline.jpg',
#     'height': 99,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-mediumFlexible177.jpg',
#     'height': 116,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-hpLarge.jpg',
#     'height': 288,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/25/opinion/25axelrodWeb/25axelrodWeb-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'The Obama Theory of Trump',
#    'kicker': 'Op-Ed Contributor',
#    'content_kicker': None,
#    'print_headline': 'The Obama Theory of Trump',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Presidential Election of 2016',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 2, 'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Polls and Public Opinion',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Voting and Voters', 'rank': 6, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Republican Party',
#     'rank': 7,
#     'major': 'N'}],
#   'pub_date': '2016-01-25T08:21:17+0000',
#   'document_type': 'article',
#   'news_desk': 'OpEd',
#   'section_name': 'Opinion',
#   'subsection_name': 'Campaign Stops',
#   'byline': {'original': 'By David Axelrod',
#    'person': [{'firstname': 'David',
#      'middlename': None,
#      'lastname': 'Axelrod',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Op-Ed',
#   '_id': 'nyt://article/ae224f9a-e4c5-53b7-9681-905a15bbc393',
#   'word_count': 1078,
#   'uri': 'nyt://article/ae224f9a-e4c5-53b7-9681-905a15bbc393'},
#  {'abstract': '“We must confront the reality that around the world anti-Semitism is on the rise,” the president urged at an event to posthumously honor individuals who protected Jews during the Holocaust.',
#   'web_url': 'https://www.nytimes.com/video/us/100000004173017/obama-speaks-at-israeli-embassy.html',
#   'snippet': '“We must confront the reality that around the world anti-Semitism is on the rise,” the president urged at an event to posthumously honor individuals who protected Jews during the Holocaust.',
#   'lead_paragraph': '“We must confront the reality that around the world anti-Semitism is on the rise,” the president urged at an event to posthumously honor individuals who protected Jews during the Holocaust.',
#   'source': 'AP',
#   'multimedia': [{'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-verticalTwoByThree735.jpg',
#     'height': 1102,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-largeWidescreen1050.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-videoSixteenByNine3000.jpg',
#     'height': 1687,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/27/multimedia/28obama-holocaust/28obama-holocaust-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'Obama Speaks at Israeli Embassy',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Anti-Semitism',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'War Crimes, Genocide and Crimes Against Humanity',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Washington (DC)', 'rank': 4, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Holocaust and the Nazi Era',
#     'rank': 5,
#     'major': 'N'}],
#   'pub_date': '2016-01-28T04:39:30+0000',
#   'document_type': 'multimedia',
#   'news_desk': 'National',
#   'section_name': 'U.S.',
#   'byline': {'original': 'By THE ASSOCIATED PRESS',
#    'person': [],
#    'organization': 'THE ASSOCIATED PRESS'},
#   'type_of_material': 'Video',
#   '_id': 'nyt://video/fdc9660c-5c0a-52e5-97ca-95e19a12f05d',
#   'word_count': 0,
#   'uri': 'nyt://video/fdc9660c-5c0a-52e5-97ca-95e19a12f05d'},
#  {'abstract': 'President Obama hosted the emir of Qatar, Sheikh Tamim bin Hamad al-Thani, on Tuesday, and both said they were committed to defeating the Islamic State and other terrorist organizations.',
#   'web_url': 'https://www.nytimes.com/video/world/100000003532966/obama-meets-with-the-emir-of-qatar.html',
#   'snippet': 'President Obama hosted the emir of Qatar, Sheikh Tamim bin Hamad al-Thani, on Tuesday, and both said they were committed to defeating the Islamic State and other terrorist organizations.',
#   'lead_paragraph': 'President Obama hosted the emir of Qatar, Sheikh Tamim bin Hamad al-Thani, on Tuesday, and both said they were committed to defeating the Islamic State and other terrorist organizations.',
#   'source': 'The New York Times',
#   'multimedia': [],
#   'headline': {'main': 'Obama Meets With the Emir of Qatar',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Obama, Barack', 'rank': 2, 'major': 'N'},
#    {'name': 'persons',
# ...
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-superJumbo.jpg',
#     'height': 1366,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-videoSixteenByNine3000.jpg',
#     'height': 1688,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2016/01/29/us/29dems-webALT/29dems-webALT-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'}],
#   'headline': {'main': 'For House Democrats, Support for Obama Agenda Came at a Cost',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Diminished House Democrats Assess Cost of Backing the Obama Agenda ',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Obama, Barack',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'United States', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Democratic Party',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Democratic Congressional Campaign Committee',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Elections, House of Representatives',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'House of Representatives',
#     'rank': 9,
#     'major': 'N'}],
#   'pub_date': '2016-01-28T16:04:56+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'U.S.',
#   'subsection_name': 'Politics',
#   'byline': {'original': 'By David M. Herszenhorn and Michael D. Shear',
#    'person': [{'firstname': 'David',
#      'middlename': None,
#      'lastname': None,
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/5a46f2e3-403e-567c-b1e1-8a0e61448db4',
#   'word_count': 1130,
#   'uri': 'nyt://article/5a46f2e3-403e-567c-b1e1-8a0e61448db4'}]

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param

# Empty list for articles
# Created a variable with an empty []
articles_list = []

# loop through pages 0-2
# <range(0,3)> == 0,1,2
# <page> will contain a default value of 10 items
for page in range(0, 3):

    # <api-key={}> api key parameter
    # <&q={}> query parameter
    # <&begin_date={}> parameter for beginning date
    # <&end_date={}> parameter for ending date
    query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
   
    # create query with page number
    # <f" "> to concatenate
    # <&page={}> page parameter
    # <{str(page)}> turns the 0,1,2 into a string
    query_url = f"{query_url}&page={str(page)}"

    # <requests.get()> function for making a GET request
    # <.json()> parsing the JSON content from the response and converts to a Python {}
    articles = requests.get(query_url).json()
    
    # Add a one second interval between queries to stay within API query limits
    # <time.sleep(seconds)> == to pause the program for one second.
    ### Control the rate of requests to an API or add pauses for synchronization purposes in multi-threaded or multi-process applications.
    time.sleep(1)

    # loop through the response and append each article to the list
    # <for article in> for loop to reiterate in articles["response"]["docs"]
    # <articles["response"]["docs"]> From the "response" {} accesses the "docs" key from the articles {}
    for article in articles["response"]["docs"]:
        
        # <.append()> adds the output 'article' into the [] of 'articles_list'
        articles_list.append(article)

# %%
# <for article in> for loop to iterate each value in 'articles_list'
for article in articles_list:
    # <article['snippet']> Accessing the ['snippet'] key within the 'article' {}
    print(article['snippet'])
    print('---------------------------')
# Out:
# In presidential elections, opposites attract.
# ---------------------------
# “We must confront the reality that around the world anti-Semitism is on the rise,” the president urged at an event to posthumously honor individuals who protected Jews during the Holocaust.
# ---------------------------
# President Obama hosted the emir of Qatar, Sheikh Tamim bin Hamad al-Thani, on Tuesday, and both said they were committed to defeating the Islamic State and other terrorist organizations.
# ---------------------------
# President Obama signed a presidential memorandum creating a White House task force on cancer.
# ---------------------------
# To function properly, the clemency process needs to be removed from the grasp of the Justice Department.
# ---------------------------
# The president seeks $4 billion to help states expand in an area he views as critical to young people’s success in a changing job market.
# ---------------------------
# Katie Beirne Fallon, the president’s legislative director, has been credited with improving his relations with lawmakers on Capitol Hill.
# ---------------------------
# The practice can lead to “devastating, lasting psychological consequences,” he said in an opinion article in The Washington Post.
# ---------------------------
# President Obama, speaking at the North American International Auto Show in Detroit, expressed sympathy and concern for residents of Flint, Mich., where there has been lead contamination in the drinking water.
# ---------------------------
# The first time the president met with House Democrats, in 2009, there were 257 of them. Now there are 188. Some point a finger at him.
# ---------------------------
# The president told Politico that politics were “meaner” than in 2008, and discussed the Democratic contest between Hillary Clinton and Bernie Sanders.
# ---------------------------
# The president, who has spoken highly of Hillary Clinton recently, will meet with Senator Bernie Sanders, whom he does not have much of a relationship with.
# ---------------------------
# Parker Sawyers and Tika Sumpter play the first couple — on their first date — in the Sundance favorite “Southside With You.”
# ---------------------------
# After Senator Bernie Sanders and President Obama met for more than 45 minutes, the senator said the president was not trying to tip the scales against him.
# ---------------------------
# Highlights from President Obama’s remarks at a town-hall style meeting in Baton Rouge, La, on Thursday.
# ---------------------------
# Mr. Obama is to appear at the embassy to remember Americans who risked their lives to save Jews during the Holocaust, his latest move to show solidarity with Israel after a historic rupture over the Iran accord.
# ---------------------------
# While not actually saying she would name Mr. Obama to the Supreme Court, Mrs. Clinton didn’t dismiss the idea either, saying “I love that.”
# ---------------------------
# “Let me tell you, there are three things that are certain in life: death, taxes, and Michelle is not running for president.” — President Obama
# ---------------------------
# When the president goes to the Illinois Capitol next month to speak, he will call for a less divisive politics, aides say.
# ---------------------------
# Dire warnings from Republicans about the effect of President Obama’s policies on employment have simply not come true.
# ---------------------------
# On a visit to the United States, Prime Minister Malcolm Turnbull of Australia met with President Obama on Tuesday to discuss the fight against the Islamic State and terror.
# ---------------------------
# President Obama expressed relief and happiness that several Americans who had been detained in Iran were returning home after the completion of a nuclear agreement with Tehran.
# ---------------------------
# The 2017 budget plan would make it easier for small businesses to form retirement savings plans for their workers.
# ---------------------------
# The White House is working with Hillary Clinton’s campaign in ways large and small. Their two staffs consult on issues and the positions she takes on the president’s policy priorities.
# ---------------------------
# The Iran case showed that the use of diplomacy was the best course.
# ---------------------------
# The president delivered his final State of the Union address on Tuesday and discussed American innovation.
# ---------------------------
# The president delivered his final State of the Union address on Tuesday and discussed economic growth.
# ---------------------------
# The president delivered his final State of the Union address on Tuesday and discussed the threat posed by the Islamic State.
# ---------------------------
# Seeking to stabilize her campaign, Mrs. Clinton linked herself repeatedly to the president in the Democratic debate.
# ---------------------------
# For many young people, the first president they consciously registered was a black man.
# ---------------------------
