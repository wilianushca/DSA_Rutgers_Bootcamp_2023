# %%
# %matplotlib ipympl

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Created a variable to store the "PATH"
car_data = pd.read_csv('../Resources/mpg.csv')
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Remove the rows with missing values in horsepower
# != means doesnt equal to 
### In other words its searching for values that dont have ?, filtering out others
car_data = car_data.loc[car_data['horsepower'] != "?"]
car_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Set the 'car name' as our index
# Used <.set_index> to change the left column
car_data = car_data.set_index('car name')

# Remove the 'origin' column
# <del> to delete the column ["origin"]
del car_data['origin']

car_data.head()
# Out:
#                             mpg  cylinders  displacement horsepower  weight  \
# car name
# chevrolet chevelle malibu  18.0          8         307.0        130    3504
# buick skylark 320          15.0          8         350.0        165    3693
# plymouth satellite         18.0          8         318.0        150    3436
# amc rebel sst              16.0          8         304.0        150    3433
# ford torino                17.0          8         302.0        140    3449
#
#                            acceleration  model year
# car name
# chevrolet chevelle malibu          12.0          70
# buick skylark 320                  11.5          70
# plymouth satellite                 11.0          70
# amc rebel sst                      12.0          70
# ford torino                        10.5          70

# %%
# Convert the "horsepower" column to numeric so the data can be used
# <pd.to_numeric> changes the data format
car_data['horsepower'] = pd.to_numeric(car_data['horsepower'])
car_data['horsepower']
# Out:
# car name
# chevrolet chevelle malibu    130
# buick skylark 320            165
# plymouth satellite           150
# amc rebel sst                150
# ford torino                  140
#                             ...
# ford mustang gl               86
# vw pickup                     52
# dodge rampage                 84
# ford ranger                   79
# chevy s-10                    82
# Name: horsepower, Length: 392, dtype: int64

# %%
# Create a scatter plot which compares MPG to horsepower
# <.plot(kind=, x=, y=, grid=, figsize=(horizontal,vertical),title=)>
car_data.plot(kind="scatter", x="horsepower", y="mpg", grid=True, figsize=(8,8),
              title="MPG Vs. Horsepower")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
