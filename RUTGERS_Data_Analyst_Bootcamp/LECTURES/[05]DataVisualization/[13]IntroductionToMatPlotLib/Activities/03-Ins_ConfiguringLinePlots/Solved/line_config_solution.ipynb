# %%
# %matplotlib inline

# %%
# Dependencies
     # Importing Usual Dependencies

import matplotlib.pyplot as plt
import numpy as np

# %%
# Set x axis and variables
     # Using < np.arange( start, end, countyby ) >
          # Using < np.sin( ) > to calculate sin on 'x_axis'
          # Using < np.cos( ) > to calculate cos on 'x_axis'

x_axis = np.arange(0, 10, 0.1)
sin = np.sin(x_axis)
cos = np.cos(x_axis)

# %%
# Draw a horizontal line with 0.25 transparency
     # Using < plt.hlines( ) > to plot horizontal lines 

plt.hlines(0, 0, 10, alpha=0.25)

# %%
# Assign plots to tuples that stores result of plot

# Each point on the sine chart is marked by a blue circle
     # Using < plt.plot( x, y, marker=' ', color=' ', labels=" " ) > twice to get the 'sine_handle' and 'cosine_handle' lines

sine_handle, = plt.plot(x_axis, sin, marker ='o', color='blue', label="Sine")

# Each point on the cosine chart is marked by a red triangle
     # Using < plt.plot( x, y, marker=' ', color=' ', labels=" " ) > twice to get the 'sine_handle' and 'cosine_handle' lines

cosine_handle, = plt.plot(x_axis, cos, marker='^', color='red', label="Cosine")

# Adds a legend and sets its location to the lower right
     # Using < plt.legend( loc=" " ) > to insert a legend and declare its position in the visualization

plt.legend(loc="lower right")

# Saves an image of our chart so that we can view it in a folder
     # Using < plt.savefig( Path ) > to save it as an image in our folder

plt.savefig("../Images/lineConfig.png")
plt.show()
