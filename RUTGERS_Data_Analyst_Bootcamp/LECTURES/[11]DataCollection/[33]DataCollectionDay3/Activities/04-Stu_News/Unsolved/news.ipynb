# %%
from splinter import Browser
from bs4 import BeautifulSoup

browser=Browser('firefox')

# %%
# Visit the URL
url = "https://globalvoices.org/page/2/"
browser.visit(url)

# Parse the HTML
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# Close the dialogue box

# %%
# Create a function to perform the web scraping
def get_summary():
    # Collect the HTML from the browser
    
    # Parse the HTML with Beautiful Soup
    
    # Save the main area of the web page to a variable
    
    # Find all the articles in the main area of the web page
    
    # Create an empty list to hold summaries
    
    # Loop through the articles
    
        # Collect the article title
        
        # Collect the article date
        
        # Remove the underscore from the date
        
        # Create the summary dictionary
        
        # Append the summary dictionary to the list
        
        
    # Return the list of summaries

# %%
# Create a loop to collect the article summaries and click to the older article pages 5 times

# %%
# Print the articles list
# Out:
# [{'header': 'May 14 will determine the future of Turkey',
#   'date': '25 01 2023'},
#  {'header': "Cambodia's Prime Minister Hun Sen orders police to find Facebook beach ‘insulter’",
#   'date': '25 01 2023'},
#  {'header': 'Over 40,000 tons of neurotoxin were stored without any protection in North Macedonia',
#   'date': '25 01 2023'},
#  {'header': '‘Joy and wonder’: Morning affirmations in preparation for Trinidad & Tobago Carnival',
#   'date': '24 01 2023'},
#  {'header': 'The band that Lukashenka declared extremist sang ‘Zhyve Belarus’ (Long live Belarus!)',
#   'date': '24 01 2023'},
#  {'header': 'Lusophone African countries condemn attacks against democracy in Brazil',
#   'date': '24 01 2023'},
#  {'header': 'Tanzanian President Suluhu ends six-year ban on political rallies, promises more reforms',
#   'date': '24 01 2023'},
#  {'header': 'How Tanzanian boxer Karim Mandonga hyped the sport back into the hearts of Kenyans',
#   'date': '24 01 2023'},
#  {'header': 'How Belize’s bright biodiversity is inextricably linked to blue carbon',
#   'date': '23 01 2023'},
#  {'header': "‘We are asking for forgiveness that we know we will never receive': In Russia, people are bringing flowers to monuments of Ukrainians",
#   'date': '23 01 2023'},
#  {'header': 'Are youth in India, now more than ever, disinterested in politics?',
#   'date': '23 01 2023'},
#  {'header': 'Usain Bolt and many other Jamaicans have been the victims of major financial fraud—and now they want answers',
#   'date': '22 01 2023'},
#  {'header': 'Anthony Joseph is the second Trinidadian in three years to win the T.S. Eliot prize for poetry',
#   'date': '21 01 2023'},
#  {'header': 'In Russia, video games are unsafe for kids. But not for the usual reasons',
#   'date': '21 01 2023'},
#  {'header': '“I will forever be the enemy of the Russian regime” says TikToker in Moldova',
#   'date': '20 01 2023'},
#  {'header': 'Tensions over Lachin Corridor linger with no breakthrough in sight',
#   'date': '20 01 2023'},
#  {'header': "Azerbaijan's forgotten schools", 'date': '20 01 2023'},
#  {'header': 'President Bukele harasses independent journalists on Twitter in El Salvador',
#   'date': '20 01 2023'},
#  {'header': '2022 was a bittersweet year for European comics',
#   'date': '19 01 2023'},
#  {'header': "Overcoming existentialist crises with music: Poland's Karolina Cicha",
#   'date': '19 01 2023'},
#  {'header': 'The Southern Caucasus has a brain drain problem',
#   'date': '19 01 2023'},
#  {'header': 'From 37 to 60,000: China’s official COVID-19 death toll data remains opaque',
#   'date': '19 01 2023'},
#  {'header': 'Abuse of children in state care in Jamaica is a problem that won’t go away, but is the system to blame?',
#   'date': '19 01 2023'},
#  {'header': 'Saudi Arabia: Call for release of two Saudi Wikipedians',
#   'date': '18 01 2023'},
#  {'header': 'Cambodia bans music video of police attacking workers in 2014',
#   'date': '18 01 2023'},
#  {'header': "Liked Shakira's new hit? Listen to these other empowering songs from the same DJ",
#   'date': '18 01 2023'},
#  {'header': 'The present and persistent problem of domestic violence in Georgia',
#   'date': '18 01 2023'},
#  {'header': 'Hmong women use TikTok to reveal marriage exploitation in Thailand',
#   'date': '18 01 2023'},
#  {'header': 'Rescued at sea, why do Rohingya refugees end up in Sri Lankan detention centers?',
#   'date': '17 01 2023'},
#  {'header': 'How the Black Star Line Festival and hip-hop could further accelerate more dynamic Pan-Africanism',
#   'date': '17 01 2023'},
#  {'header': 'The unprotected: Police offer scant safety for Azerbaijan’s LGBTQ+ community',
#   'date': '17 01 2023'},
#  {'header': "Why was the major COVID-19 drug Paxlovid delisted from China's medical insurance scheme?",
#   'date': '17 01 2023'},
#  {'header': 'Relatives of drafted soldiers in Russia do not know if they are dead or alive',
#   'date': '16 01 2023'},
#  {'header': 'Money may not grow on trees, but in Nepal it grows on bushes',
#   'date': '13 01 2023'},
#  {'header': 'Infrastructural content moderation: the case of Mariupol',
#   'date': '13 01 2023'},
#  {'header': 'Kenyan Museum photo exhibit celebrates Africans’ contribution to archeology in colonial era',
#   'date': '13 01 2023'},
#  {'header': 'Thailand’s new ministerial decree could further suppress free speech online',
#   'date': '13 01 2023'},
#  {'header': 'BBC Bangla issues its final broadcast after 81 years',
#   'date': '12 01 2023'},
#  {'header': 'Will a yurt in Ukraine cause a diplomatic row between Kazakhstan and Russia?',
#   'date': '12 01 2023'},
#  {'header': 'The Tanabra have made a comeback after 100 years. A decline in Sudanese taste in music?',
#   'date': '12 01 2023'},
#  {'header': "Bolsonaro supporters attempt coup, storming Brazil's three powers headquarters",
#   'date': '12 01 2023'},
#  {'header': 'How political gaslighting undermines public policy; a case study of South Africa, Brazil and the United States',
#   'date': '12 01 2023'},
#  {'header': 'The borders between Hong Kong and China reopen ahead of Lunar New Year',
#   'date': '12 01 2023'},
#  {'header': 'Seven ways Moldova made its citizens proud in 2022',
#   'date': '12 01 2023'},
#  {'header': 'Undertones in India: Going undercover in Hindu supremacy networks',
#   'date': '11 01 2023'},
#  {'header': 'Czech presidential elections 2023: The rector, the oligarch and the general',
#   'date': '11 01 2023'},
#  {'header': 'Rights organization OVD-Info gives an overview of repression in Russia in 2022',
#   'date': '11 01 2023'},
#  {'header': 'Announcing the Mayan Languages Digital Activism Summit (January 11-15)',
#   'date': '10 01 2023'},
#  {'header': 'Bolsonaro kept religious element in public appearances, amidst protests and the end of this term',
#   'date': '10 01 2023'},
#  {'header': 'Lula returns to a divided country in historic comeback as Brazil’s president',
#   'date': '10 01 2023'},
#  {'header': '‘Hacking should be used to wake up and rebel,’ says hacker group Guacamaya',
#   'date': '10 01 2023'},
#  {'header': 'Saudi Arabia: Government agents infiltrate Wikipedia, sentence independent admins to prison',
#   'date': '10 01 2023'},
#  {'header': 'How Zimbabwe is building a Big Brother surveillance state',
#   'date': '10 01 2023'},
#  {'header': "Is Trinidad & Tobago Carnival's ‘Fantastic Friday’ big enough for two major soca events?",
#   'date': '9 01 2023'},
#  {'header': 'Kosovo: Six attacks against journalists in December following escalating tensions',
#   'date': '6 01 2023'},
#  {'header': 'New stringent legislation threatens data privacy and surveillance protection in Tanzania',
#   'date': '6 01 2023'},
#  {'header': "The film ‘Burning Days’ is a grim reflection of Turkey's current political situation",
#   'date': '6 01 2023'},
#  {'header': 'Popular Russian singer answers ‘Glory to Ukraine’. Now they want to revoke his citizenship',
#   'date': '5 01 2023'},
#  {'header': 'The construction of the 5G network brings the demise of the Chinese domination in North Macedonia’s telecommunications',
#   'date': '5 01 2023'},
#  {'header': 'Filipino activists decry Facebook’s ‘automated censorship’',
#   'date': '5 01 2023'},
#  {'header': 'Turkey’s state religious body says women cannot travel alone',
#   'date': '5 01 2023'},
#  {'header': 'Beijing empowers Hong Kong Chief Executive to direct local courts on national security-related trials',
#   'date': '5 01 2023'},
#  {'header': 'Indigenous and proud: A Maya-speaker’s reaction to ‘Black Panther: Wakanda Forever’',
#   'date': '5 01 2023'},
#  {'header': 'The first lady of Azerbaijan is a UNESCO goodwill ambassador no more',
#   'date': '4 01 2023'},
#  {'header': 'Global Voices seeks an editor to lead our Greater Central Asia coverage',
#   'date': '3 01 2023'},
#  {'header': 'Global Voices seeks a policy advocacy coordinator',
#   'date': '3 01 2023'},
#  {'header': 'Undertones in Russia: War, Propaganda, the West',
#   'date': '3 01 2023'},
#  {'header': 'China falls into a chaos amid a Tsunami-scale winter COVID-19 outbreak',
#   'date': '3 01 2023'},
#  {'header': 'Artists reimagine Jamaica’s Nanny of the Maroons as much more than a warrior queen',
#   'date': '2 01 2023'},
#  {'header': 'What’s Eritrean President Isaias Afwerki’s next move after a dubious truce?',
#   'date': '2 01 2023'},
#  {'header': 'Can a literary festival bring Nepali literature to the international stage?',
#   'date': '2 01 2023'},
#  {'header': "Mountain Jews: A glimpse into the life of one of Azerbaijan's minorities",
#   'date': '2 01 2023'},
#  {'header': 'China’s Belt and Road Initiative divides the Pacific',
#   'date': '2 01 2023'},
#  {'header': 'Simple, seldom and sad — the weight of anniversaries',
#   'date': '1 01 2023'},
#  {'header': 'Russia weaponizes cultural awards: It’s not all the same who is awarding a prize',
#   'date': '31 12 2022'},
#  {'header': "France's institutional fear of multilingualism: An interview with language activist Michel Feltin-Palas",
#   'date': '30 12 2022'},
#  {'header': 'European Parliament’s Report on Pegasus spyware indicates involvement of North Macedonia companies',
#   'date': '29 12 2022'},
#  {'header': 'Welcome the new year with these joyful traditions from Latin America',
#   'date': '29 12 2022'},
#  {'header': 'A Buryat voice calling on Russia to decolonize : Interview with Instagrammer Seseg Jigjitova',
#   'date': '29 12 2022'},
#  {'header': 'The year in review: What the Caribbean looked like in 2022',
#   'date': '29 12 2022'},
#  {'header': "Trinidad & Tobago's calypsonian Black Stalin, the quintessential ‘Caribbean Man,’ dies at 81",
#   'date': '28 12 2022'},
#  {'header': "Turkey's Saturday Mothers, 27 years on, are still searching for justice and closure",
#   'date': '27 12 2022'},
#  {'header': 'How Morocco’s Atlas Lions made history at the 2022 World Cup',
#   'date': '27 12 2022'},
#  {'header': "Inside my bounty: Raghda's journey", 'date': '27 12 2022'},
#  {'header': "For school New Year's Eve parties in Moscow, some music is apparently deemed inappropriate",
#   'date': '27 12 2022'},
#  {'header': 'Self-taught Trinidadian photographer Jason C. Audain pushes boundaries with the use of AI',
#   'date': '27 12 2022'},
#  {'header': 'The Dutch state apologises for slavery, and the Caribbean wonders: Will reparations follow?',
#   'date': '26 12 2022'},
#  {'header': 'Climate change, digital authoritarianism and disinformation campaigns ruled in South Asia in 2022',
#   'date': '26 12 2022'},
#  {'header': "‘The Balkans are Europe's Latin America in many beautiful ways,’ says Albanian writer",
#   'date': '25 12 2022'},
#  {'header': 'This online game exposes the dangers of deep-sea mining',
#   'date': '25 12 2022'},
#  {'header': 'Classical dance pushes the bounds of traditional gender identities in Cambodia',
#   'date': '24 12 2022'},
#  {'header': 'Turkey, a year in review: Battling both at home and abroad',
#   'date': '24 12 2022'},
#  {'header': "Police in Azerbaijan detain protesters on the day of activist's trial",
#   'date': '24 12 2022'},
#  {'header': 'Governments are still free to use the Pegasus software without human rights safeguards in place',
#   'date': '23 12 2022'},
#  {'header': 'Pundits say unblocking the Lachin Corridor is the only way to avoid humanitarian crisis',
#   'date': '23 12 2022'},
#  {'header': 'Another attack on LGBTQ+ center in Podgorica highlights the need to protect human rights in Montenegro',
#   'date': '23 12 2022'},
#  {'header': 'Documentary about the 1920s Volga famine is prohibited in Russia but broadcasted on YouTube',
#   'date': '22 12 2022'},
#  {'header': 'Transgender women are despised, like the Virgin Mary in her day',
#   'date': '22 12 2022'},
#  {'header': 'Undertones in Afghanistan: ‘Taliban 2.0,’ Women, Resistance',
#   'date': '21 12 2022'},
#  {'header': 'A fact-check of India’s socio-political undercurrents: the case of Zubair',
#   'date': '21 12 2022'},
#  {'header': "Woman dubbed ‘Messi's grandma’ goes viral in Argentina following World Cup win",
#   'date': '21 12 2022'},
#  {'header': "Art curator Mark Pereira's murder during a home invasion leaves Trinbagonian netizens nervous about crime",
#   'date': '21 12 2022'},
#  {'header': "What is Hong Kong role in Russia's sanction evasion?",
#   'date': '21 12 2022'},
#  {'header': 'Australia explores ways to combat widespread greenwashing of carbon emissions',
#   'date': '20 12 2022'},
#  {'header': 'Hong Kong launches a national security legal battle against media tycoon Jimmy Lai',
#   'date': '20 12 2022'}]

# %%
# Import Pandas

# Convert the articles list to a Pandas DataFrame
# Out:
#                                               header        date
# 0         May 14 will determine the future of Turkey  25 01 2023
# 1  Cambodia's Prime Minister Hun Sen orders polic...  25 01 2023
# 2  Over 40,000 tons of neurotoxin were stored wit...  25 01 2023
# 3  ‘Joy and wonder’: Morning affirmations in prep...  24 01 2023
# 4  The band that Lukashenka declared extremist sa...  24 01 2023

# %%
# Convert the date column to a datetime data type

# %%
# Display the DataFrame
# Out:
#                                                 header       date
# 0           May 14 will determine the future of Turkey 2023-01-25
# 1    Cambodia's Prime Minister Hun Sen orders polic... 2023-01-25
# 2    Over 40,000 tons of neurotoxin were stored wit... 2023-01-25
# 3    ‘Joy and wonder’: Morning affirmations in prep... 2023-01-24
# 4    The band that Lukashenka declared extremist sa... 2023-01-24
# ..                                                 ...        ...
# 100  Woman dubbed ‘Messi's grandma’ goes viral in A... 2022-12-21
# 101  Art curator Mark Pereira's murder during a hom... 2022-12-21
# 102  What is Hong Kong role in Russia's sanction ev... 2022-12-21
# 103  Australia explores ways to combat widespread g... 2022-12-20
# 104  Hong Kong launches a national security legal b... 2022-12-20
#
# [105 rows x 2 columns]

# %%
# Check the DataFrame information to ensure the date is saved as a datetime data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   header  105 non-null    object
#  1   date    105 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 1.8+ KB

# %%
# Close the browser
browser.quit()
